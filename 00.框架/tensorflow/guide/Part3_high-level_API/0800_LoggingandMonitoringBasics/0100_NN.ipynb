# %% [markdown]
# ### import
# - **设置日志级别**

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import os
import urllib.request
import numpy as np
import tensorflow as tf

# 设置日志级别
tf.logging.set_verbosity(tf.logging.INFO)

# %% [markdown]
# ### get data

# %%
# Data sets
IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"
IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

# If the training and test sets aren't stored locally, download them.
if not os.path.exists(IRIS_TRAINING):
    raw = urllib.request.urlopen(IRIS_TRAINING_URL).read()
    with open(IRIS_TRAINING, "wb") as f:
        f.write(raw)

if not os.path.exists(IRIS_TEST):
    raw = urllib.request.urlopen(IRIS_TEST_URL).read()
    with open(IRIS_TEST, "wb") as f:
        f.write(raw)

# Load datasets.
training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TRAINING, target_dtype=np.int, features_dtype=np.float32)
test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TEST, target_dtype=np.int, features_dtype=np.float32)

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

# %% [markdown]
# ### dataset utils
# 由于数据量很小，可以把数据定义在常量中

# %%
# Define the training inputs
def get_train_inputs():
    x = tf.constant(training_set.data)
    y = tf.constant(training_set.target)
    return x, y

# Define the test inputs
def get_test_inputs():
    x = tf.constant(test_set.data)
    y = tf.constant(test_set.target)
    return x, y

# Classify two new flower samples.
def new_samples():
    return np.array([[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)

# %% [markdown]
# ### train and test
# - **用ValidationMonitor每隔N步在测试集上验证一次准确率**
#     1. 首先定义validation_monitor
#     2. 在fit时加上monitors=[validation_monitor]
#
# - **ValidationMonitor的使用依赖于checkpoints,初始化classifier时用`config = tf.contrib.learn.RunConfig(save_checkpoints_secs=1)`配置tf每1秒保存一下checkpoints**
#
# - **可以自定义log中显示的validation_metrics**
# - **让训练提前终止**
# ```
#     early_stopping_metric="loss",
#     early_stopping_metric_minimize=True,
#     early_stopping_rounds=200
# ```

# %%
# 定义log中要显示的validation_metrics
validation_metrics = {
    "accuracy":
        tf.contrib.learn.MetricSpec(
            metric_fn=tf.contrib.metrics.streaming_accuracy,
            prediction_key=tf.contrib.learn.PredictionKey.CLASSES),
    "precision":
        tf.contrib.learn.MetricSpec(
            metric_fn=tf.contrib.metrics.streaming_precision,
            prediction_key=tf.contrib.learn.PredictionKey.CLASSES),
    "recall":
        tf.contrib.learn.MetricSpec(
            metric_fn=tf.contrib.metrics.streaming_recall,
            prediction_key=tf.contrib.learn.PredictionKey.CLASSES)
}

# 用ValidationMonitor每隔N步在测试集上验证一次准确率
validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    test_set.data,
    test_set.target,
    every_n_steps=50,
    metrics=validation_metrics, 
    early_stopping_metric="loss",
    early_stopping_metric_minimize=True,
    early_stopping_rounds=200
)

# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(
    feature_columns=feature_columns,
    hidden_units=[10, 20, 10],
    n_classes=3, 
    model_dir="/tmp/iris_model",
    config = tf.contrib.learn.RunConfig(save_checkpoints_secs=1)
)

# Fit model.
classifier.fit(input_fn=get_train_inputs, steps=2000, monitors=[validation_monitor])

# Evaluate accuracy.
accuracy_score = classifier.evaluate(input_fn=get_test_inputs, steps=1)["accuracy"]
print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

predictions = list(classifier.predict(input_fn=new_samples))
print("New Samples, Class Predictions: {}\n".format(predictions))
# Out:
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:268: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using config: {'_tf_random_seed': None, '_save_checkpoints_secs': 1, '_save_checkpoints_steps': None, '_task_id': 0, '_session_config': None, '_environment': 'local', '_keep_checkpoint_every_n_hours': 10000, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_num_worker_replicas': 0, '_save_summary_steps': 100, '_is_chief': True, '_num_ps_replicas': 0, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020682D91BA8>, '_model_dir': '/tmp/iris_model', '_task_type': None, '_master': '', '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:step = 1, loss = 1.2755
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:22
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:23
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.266667, global_step = 1, loss = 1.07558, precision = 0.733333, recall = 1.0
# INFO:tensorflow:Validation (step 50): global_step = 1, accuracy = 0.266667, recall = 1.0, precision = 0.733333, loss = 1.07558
# INFO:tensorflow:Saving checkpoints for 51 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:24
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-51
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:24
# INFO:tensorflow:Saving dict for global step 51: accuracy = 0.933333, global_step = 51, loss = 0.286205, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 100): global_step = 51, accuracy = 0.933333, recall = 1.0, precision = 1.0, loss = 0.286205
# INFO:tensorflow:Saving checkpoints for 101 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 30.8515
# INFO:tensorflow:step = 101, loss = 0.174001 (3.243 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:25
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-101
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:26
# INFO:tensorflow:Saving dict for global step 101: accuracy = 0.966667, global_step = 101, loss = 0.154192, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 150): global_step = 101, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.154192
# INFO:tensorflow:Saving checkpoints for 151 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:27
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-151
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:27
# INFO:tensorflow:Saving dict for global step 151: accuracy = 0.966667, global_step = 151, loss = 0.101613, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 200): global_step = 151, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.101613
# INFO:tensorflow:Saving checkpoints for 201 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 37.6486
# INFO:tensorflow:step = 201, loss = 0.0964596 (2.656 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:28
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-201
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:28
# INFO:tensorflow:Saving dict for global step 201: accuracy = 0.966667, global_step = 201, loss = 0.0799421, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 250): global_step = 201, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0799421
# INFO:tensorflow:Saving checkpoints for 251 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:29
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-251
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:30
# INFO:tensorflow:Saving dict for global step 251: accuracy = 0.966667, global_step = 251, loss = 0.0692118, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 300): global_step = 251, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0692118
# INFO:tensorflow:Saving checkpoints for 301 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 36.6154
# INFO:tensorflow:step = 301, loss = 0.0751932 (2.731 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:31
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-301
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:31
# INFO:tensorflow:Saving dict for global step 301: accuracy = 0.966667, global_step = 301, loss = 0.0621895, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 350): global_step = 301, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0621895
# INFO:tensorflow:Saving checkpoints for 351 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:32
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-351
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:33
# INFO:tensorflow:Saving dict for global step 351: accuracy = 0.966667, global_step = 351, loss = 0.058949, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 400): global_step = 351, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.058949
# INFO:tensorflow:Saving checkpoints for 401 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 38.1753
# INFO:tensorflow:step = 401, loss = 0.0678403 (2.620 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:33
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-401
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:34
# INFO:tensorflow:Saving dict for global step 401: accuracy = 0.966667, global_step = 401, loss = 0.0558684, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 450): global_step = 401, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0558684
# INFO:tensorflow:Saving checkpoints for 451 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:35
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-451
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:35
# INFO:tensorflow:Saving dict for global step 451: accuracy = 0.966667, global_step = 451, loss = 0.0544005, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 500): global_step = 451, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0544005
# INFO:tensorflow:Saving checkpoints for 501 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 36.4919
# INFO:tensorflow:step = 501, loss = 0.0632844 (2.739 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:36
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-501
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:37
# INFO:tensorflow:Saving dict for global step 501: accuracy = 0.966667, global_step = 501, loss = 0.0529991, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 550): global_step = 501, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0529991
# INFO:tensorflow:Saving checkpoints for 551 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:37
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-551
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:38
# INFO:tensorflow:Saving dict for global step 551: accuracy = 0.966667, global_step = 551, loss = 0.0523004, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 600): global_step = 551, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0523004
# INFO:tensorflow:Saving checkpoints for 601 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 35.7246
# INFO:tensorflow:step = 601, loss = 0.0601866 (2.801 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:39
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-601
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:39
# INFO:tensorflow:Saving dict for global step 601: accuracy = 0.966667, global_step = 601, loss = 0.0516874, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 650): global_step = 601, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0516874
# INFO:tensorflow:Saving checkpoints for 651 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:40
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-651
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:41
# INFO:tensorflow:Saving dict for global step 651: accuracy = 0.966667, global_step = 651, loss = 0.0512633, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 700): global_step = 651, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0512633
# INFO:tensorflow:Saving checkpoints for 701 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 35.6537
# INFO:tensorflow:step = 701, loss = 0.0578337 (2.803 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:42
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-701
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:42
# INFO:tensorflow:Saving dict for global step 701: accuracy = 0.966667, global_step = 701, loss = 0.0511266, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 750): global_step = 701, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0511266
# INFO:tensorflow:Saving checkpoints for 751 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:43
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-751
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:44
# INFO:tensorflow:Saving dict for global step 751: accuracy = 0.966667, global_step = 751, loss = 0.0509814, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 800): global_step = 751, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0509814
# INFO:tensorflow:Saving checkpoints for 801 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 34.5066
# INFO:tensorflow:step = 801, loss = 0.0559485 (2.899 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:45
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-801
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:45
# INFO:tensorflow:Saving dict for global step 801: accuracy = 0.966667, global_step = 801, loss = 0.0509856, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 850): global_step = 801, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0509856
# INFO:tensorflow:Saving checkpoints for 851 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:46
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-851
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:47
# INFO:tensorflow:Saving dict for global step 851: accuracy = 0.966667, global_step = 851, loss = 0.0510519, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 900): global_step = 851, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0510519
# INFO:tensorflow:Saving checkpoints for 901 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:global_step/sec: 34.6531
# INFO:tensorflow:step = 901, loss = 0.0543923 (2.886 sec)
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:48
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-901
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:48
# INFO:tensorflow:Saving dict for global step 901: accuracy = 0.966667, global_step = 901, loss = 0.0511195, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 950): global_step = 901, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.0511195
# INFO:tensorflow:Saving checkpoints for 951 into /tmp/iris_model\model.ckpt.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:653: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:49
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-951
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:49
# INFO:tensorflow:Saving dict for global step 951: accuracy = 0.966667, global_step = 951, loss = 0.051386, precision = 1.0, recall = 1.0
# INFO:tensorflow:Validation (step 1000): global_step = 951, accuracy = 0.966667, recall = 1.0, precision = 1.0, loss = 0.051386
# INFO:tensorflow:Stopping. Best step: 800 with loss = 0.050981368869543076.
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/iris_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0530392.
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-25-03:05:50
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-1000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-06-25-03:05:51
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.966667, global_step = 1000, loss = 0.0495608
#
# Test Accuracy: 0.966667
#
# WARNING:tensorflow:From d:\program files\python35\lib\site-packages\tensorflow\python\util\deprecation.py:347: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model\model.ckpt-1000
# New Samples, Class Predictions: [1, 2]
